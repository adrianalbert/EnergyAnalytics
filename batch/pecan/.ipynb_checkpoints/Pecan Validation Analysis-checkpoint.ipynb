# %% [markdown]
# #Pecan validation analysis

# %% [markdown]
# Here we perform analysis on the model vs ground truth data for thermal and occupancy consumption. We contrast two models:
# * ground truth thermal response: a locally-weighted regression model using separately-monitored HVAC and temperature
# * the HMM thermal model

# %% [markdown]
# ##Initializations

# %%
rm(list = ls())

# %%
options(error = recover)
library('segmented')
library('lubridate')
library('ggplot2')
library(zoo)
# Out:
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
setwd("~/EnergyAnalytics/thermal_profiles/")
#source('validator/metrics.r')
source('validator/plot_metrics.r')
# Out:
# Attaching package: ‘reshape’
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
#
#
# Attaching package: ‘gplots’
#
# The following object is masked from ‘package:stats’:
#
#     lowess

# %%
DATA_PATH = '~/S3L_server/energy-data/pecan_street/usage-select/'
DUMP_PATH = '~/S3L_server/energy-data/pecan_street/models_new/'
PLOT_PATH = '~/S3L_server/plots/pecan-street-new/'
MODEL_PATH= '~/S3L_server/energy-data/pecan_street/models_new/'

# %% [markdown]
# Paths to original data

# %%
# load user names
user_names = read.csv('~/S3L_server/energy-data/pecan_street/metadata/user_names_ids.csv')
user_names$X = NULL

# list all data files
files    = list.files(path=DATA_PATH, full.names = T, recursive = T)
files_01 = files[grep('01min',files)]
files_15 = files[grep('15min',files)]
files_60 = files[grep('60min',files)]

# extract ID
users_df = data.frame(UID = as.character(sapply(files_60, function(s) strsplit(tail(strsplit(s, '/')[[1]], 1), '\\.')[[1]][1])))
rownames(users_df) = NULL
    
# build original data sources dataframe
users_df = merge(users_df, user_names, by.x="UID", by.y="ID")
users_df['01min'] = files_01
users_df['15min'] = files_15
users_df['60min'] = files_60
users_df = melt(users_df, id=c("UID","name"))
names(users_df)[c(3,4)] = c("grain", "file_orig")

# %%
users_df[1,]
# Out:
#    UID name grain
# 1 1069  Edd 01min
#                                                                              file_orig
# 1 /Users/adrianalbert/S3L_server/energy-data/pecan_street/usage-select//01min/1069.csv

# %% [markdown]
# Paths to thermal models data

# %%
# models 
files_dec = list.files(path=MODEL_PATH, pattern="*decoded", full.names = T, recursive = T)
files_int = list.files(path=MODEL_PATH, pattern="*interpreted", full.names = T, recursive = T)
f_dum = function(x) {
    tmp = tail(strsplit(x, '/')[[1]],n=2)
    res = tmp[1]
    nfo = strsplit(tmp[2], "_")[[1]]
    uid = nfo[1]; name = nfo[2]; 
    return(c(uid,name,res,x))
}
model_paths_dec = data.frame(do.call('rbind', lapply(files_dec, f_dum)))
model_paths_int = data.frame(do.call('rbind', lapply(files_int, f_dum)))

if (length(model_paths_dec)>0) names(model_paths_dec) <- c("UID", "name", "grain", "file_model")
if (length(model_paths_int)>0) names(model_paths_int) <- c("UID", "name", "grain", "file_model")
model_paths = merge(model_paths_dec, model_paths_int, by=c("UID", "name", "grain"), suffixes=c("_decode", "_interp"))

# %%
head(model_paths_int)
# Out:
#    UID  name grain
# 1 1069   Edd 15min
# 2 1069   Edd 60min
# 3 1086 Emery 15min
# 4 1086 Emery 60min
# 5 1105 Grant 15min
# 6 1105 Grant 60min
#                                                                                                          file_model
# 1     /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1069_Edd/15min/1069_Edd_interpreted.RData
# 2     /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1069_Edd/60min/1069_Edd_interpreted.RData
# 3 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1086_Emery/15min/1086_Emery_interpreted.RData
# 4 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1086_Emery/60min/1086_Emery_interpreted.RData
# 5 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1105_Grant/15min/1105_Grant_interpreted.RData
# 6 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1105_Grant/60min/1105_Grant_interpreted.RData

# %%
info_files = merge(model_paths, users_df, by=c("UID", "name", "grain"))
info_files = info_files[with(info_files, order(UID,grain,name)),]

# %%
dim(info_files); dim(model_paths); dim(users_df)
# Out:
# [1] 515   6
# [1] 515   5
# [1] 1098    4

# %%
head(info_files)
# Out:
#    UID  name grain
# 1 1069   Edd 15min
# 2 1069   Edd 60min
# 3 1086 Emery 15min
# 4 1086 Emery 60min
# 5 1105 Grant 15min
# 6 1105 Grant 60min
#                                                                                               file_model_decode
# 1     /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1069_Edd/15min/1069_Edd_decoded.RData
# 2     /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1069_Edd/60min/1069_Edd_decoded.RData
# 3 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1086_Emery/15min/1086_Emery_decoded.RData
# 4 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1086_Emery/60min/1086_Emery_decoded.RData
# 5 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1105_Grant/15min/1105_Grant_decoded.RData
# 6 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1105_Grant/60min/1105_Grant_decoded.RData
# ...

# %% [markdown]
# ##Load processed thermal regimes data

# %%
thermal_lst = list()
for (i in 1:nrow(info_files)) {
    print(paste("Processing file", i, "of", nrow(info_files)))
    row <- info_files[i,]
    load(as.character(as.character(row$file_model_decode)));
    df = data$df
    
    if (nrow(data$states) != nrow(df)) next
        
    # access data    
    nStates= data$nStates
    df     = cbind(df, data$state)
    df$TemperatureD = df$TemperatureF - 65
    resp   = data$response   
    tran   = data$transition
    tran   = lapply(unique(tran$From), function(s) {d = subset(tran, To ==s); d$From = d$To = NULL; rownames(d) = 1:nrow(d); return(d)})

    # check for consistency
    if (class(resp$stderr) == 'list') {
      idx.nan = which(sapply(resp$stderr, length) < 2)    
      z = c(0,0,0); names(z) = c('(Intercept)', 'TemperatureD')
      for (i in 1:length(idx.nan)) {
        tmp = resp$stderr[[idx.nan[i]]]
        z[names(tmp)] = tmp
        resp$stderr[[idx.nan[i]]] = z
      }
      resp$stderr = as.data.frame(do.call('cbind', resp$stderr))
      names(resp$stderr) = 1:ncol(resp$stderr)
    }

    # format model parameters for easy analysis access
    volatility = lapply(1:nStates, function(s) { z = c(mu = 0, sd = resp$stdev[s]); names(z) = c('mu', 'sd'); z})
    baseload   = lapply(1:nStates, function(s) { z = c(mu = resp$means['(Intercept)', s], sd = resp$stderr['(Intercept)', s]); names(z) = c('mu', 'sd'); z})
    response   = lapply(1:nStates, function(s) c(mu = resp$means['TemperatureD', s], sd = as.numeric(resp$stderr['TemperatureD', s])))
    
    df$resp_MAP   = sapply(df$state, function(s) response[[s]]['mu'])
    df$resp_MAP.se= sapply(df$state, function(s) response[[s]]['sd'])
    tmp = df[grepl("X[1-9]", names(df))] * matrix(unlist(response), nrow=2)
    df$resp_avg   = rowSums(tmp[1,])
    df$resp_avg.se= apply(tmp[1,], 1, sd)
    
    res = list(volatility = volatility, baseload = baseload, response = response, tran = tran, data = df)
    thermal_lst[[as.character(row$name)]][[as.character(row$grain)]] = res
}

# %% [markdown]
# ##Estimate "ground truth" thermal response

# %%
info_files[5,]
# Out:
#    UID  name grain
# 5 1105 Grant 15min
#                                                                                                      file_model
# 5 /Users/adrianalbert/S3L_server/energy-data/pecan_street/models_new//1105_Grant/15min/1105_Grant_decoded.RData
#                                                                              file_orig
# 5 /Users/adrianalbert/S3L_server/energy-data/pecan_street/usage-select//15min/1105.csv

# %%
# format data to match the observations available for thermal modeling
row <- info_files[18,]
df_orig = read.csv(as.character(row$file_orig))
df_orig$HVAC = 0
if ('HV' %in% names(df_orig)) df_orig$HVAC = df_orig$HVAC + df_orig$HV
if ('AC' %in% names(df_orig)) df_orig$HVAC = df_orig$HVAC + df_orig$AC
df_orig$TemperatureD = df_orig$TemperatureF - 65
df_orig = subset(df_orig, date %in% data$df$timestamps)
cur_info = paste(row$name
    
# select only non-zero observations
thresh = quantile(df_orig$HVAC[df_orig$HVAC>0], 0.25)
df_nonz = subset(df_orig, HVAC>thresh)
print(thresh)
# Out:
# [1] 2664   10
#    25%
# 0.0036

# %%
temp_vec = 20:120
df_resp = data.frame(TemperatureF = temp_vec)

fit = loess(HVAC ~ TemperatureD, data=df_orig)
plx = predict(fit, se=T)
df_orig$fit_HVAC = plx$fit
df_orig$fit_HVAC_se = plx$se.fit
plx_grid = predict(fit, temp_vec - 65, se=T)
df_resp$fit_HVAC    = na.locf(na.locf(plx_grid$fit, na.rm=FALSE), fromLast=TRUE)
df_resp$fit_HVAC.se = na.locf(na.locf(plx_grid$se.fit, na.rm=FALSE), fromLast=TRUE)
df_resp$resp_HVAC   = na.locf(na.locf(c(NA,diff(plx_grid$fit)), na.rm=FALSE), fromLast=TRUE)
df_orig$resp_HVAC   = approx(df_resp$TemperatureF, y=df_resp$resp_HVAC, df_orig$TemperatureF)$y

# learn "ground truth" thermal response for HV and AC
if ('HV' %in% names(df_orig))
    fit = loess(HV ~ TemperatureD, data=df_orig)
    plx = predict(fit, se=T)
    df_orig$fit_HV = plx$fit
    df_orig$fit_HV_se = plx$se.fit
    plx_grid = predict(fit, temp_vec - 65, se=T)
    df_resp$fit_HV    = na.locf(na.locf(plx_grid$fit, na.rm=FALSE), fromLast=TRUE)
    df_resp$fit_HV.se = na.locf(na.locf(plx_grid$se.fit, na.rm=FALSE), fromLast=TRUE)
    df_resp$resp_HV   = na.locf(na.locf(c(NA,diff(plx_grid$fit)), na.rm=FALSE), fromLast=TRUE)
    df_orig$resp_HV   = approx(df_resp$TemperatureF, y=df_resp$resp_HV, df_orig$TemperatureF)$y

if ('AC' %in% names(df_orig))
    fit = loess(AC ~ TemperatureD, data=df_orig)
    plx = predict(fit, se=T)
    df_orig$fit_AC = plx$fit
    df_orig$fit_AC_se = plx$se.fit
    plx_grid = predict(fit, temp_vec - 65, se=T)
    df_resp$fit_AC    = na.locf(na.locf(plx_grid$fit, na.rm=FALSE), fromLast=TRUE)
    df_resp$fit_AC.se = na.locf(na.locf(plx_grid$se.fit, na.rm=FALSE), fromLast=TRUE)
    df_resp$resp_AC   = na.locf(na.locf(c(NA,diff(plx_grid$fit)), na.rm=FALSE), fromLast=TRUE)
    df_orig$resp_AC   = approx(df_resp$TemperatureF, y=df_resp$resp_AC, df_orig$TemperatureF)$y

# %%
head(df_resp)
# Out:
#   TemperatureF  fit_HVAC fit_HVAC.se   resp_HVAC    fit_HV  fit_HV.se
# 1           20 0.7944964  0.04876400 -0.05083986 0.7953034 0.04089142
# 2           21 0.7944964  0.04876400 -0.05083986 0.7953034 0.04089142
# 3           22 0.7944964  0.04876400 -0.05083986 0.7953034 0.04089142
# 4           23 0.7436566  0.04401284 -0.05083986 0.7446049 0.03690730
# 5           24 0.6946241  0.03955088 -0.04903243 0.6956260 0.03316570
# 6           25 0.6474136  0.03538723 -0.04721056 0.6483809 0.02967423
#       resp_HV        fit_AC  fit_AC.se       resp_AC
# 1 -0.05069848 -0.0008069263 0.02414558 -1.413806e-04
# 2 -0.05069848 -0.0008069263 0.02414558 -1.413806e-04
# 3 -0.05069848 -0.0008069263 0.02414558 -1.413806e-04
# 4 -0.05069848 -0.0009483070 0.02179304 -1.413806e-04
# 5 -0.04897892 -0.0010018207 0.01958369 -5.351374e-05
# 6 -0.04724507 -0.0009673024 0.01752205  3.451832e-05

# %%
head(df_orig)
# Out:
#                     date       use AC          HV       user    lights
# 2256 2013-12-10 16:00:00 0.1192667  0 0.003266667 0.04846667 0.0360000
# 2257 2013-12-10 17:00:00 1.8549167  0 0.000000000 0.03870000 0.0360000
# 2258 2013-12-10 18:00:00 1.7488833  0 1.268766667 0.07620000 0.1075167
# 2259 2013-12-10 19:00:00 0.7415167  0 0.000000000 0.06840000 0.1391167
# 2260 2013-12-10 20:00:00 0.5380667  0 0.003550000 0.06550000 0.1589833
# 2261 2013-12-10 21:00:00 0.3783833  0 0.003666667 0.03126667 0.1459667
#        nonHVAC TemperatureF        HVAC TemperatureD     fit_HV  fit_HV_se
# 2256 0.1160000     46.22333 0.003266667    -18.77667 0.06809869 0.01036297
# 2257 1.8549167     44.93500 0.000000000    -20.06500 0.08178331 0.01011705
# 2258 0.4801167     41.90000 1.268766667    -23.10000 0.12399002 0.01020426
# 2259 0.7415167     39.29167 0.000000000    -25.70833 0.17150093 0.01009171
# 2260 0.5345167     37.28167 0.003550000    -27.71833 0.21528847 0.01018839
# ...

# %%
pdf(file = paste(path_plots, user_info, sep='/'), 10, 7)
# plot response
v = df_resp$resp_HVAC
if ('AC' %in% names(df_orig)) v = c(v, df_resp$resp_AC)
if ('HV' %in% names(df_orig)) v = c(v, df_resp$resp_HV)
ylim_resp = range(v)
plot(df_resp$TemperatureF, df_resp$resp_HVAC, col='green', type='l', lwd=5, 
     cex.main=2, 
     cex.lab=1.5,
     cex.axis=1.2, 
     ylim=ylim_resp,
     main="Ground Truth Thermal Response", 
     xlab="Temperature (deg F)", ylab="Response (kwh/deg F)")

if ('AC' %in% names(df_orig))
    points(df_resp$TemperatureF, df_resp$resp_AC, col='blue', type='l', lwd=5) 

if ('HV' %in% names(df_orig))
    points(df_resp$TemperatureF, df_resp$resp_HV, col='red', type='l', lwd=5) 

legend("bottomright", intersect(c("HVAC", "AC", "HV"), names(df_orig)), 
       lty=c(1,1), # gives the legend appropriate symbols (lines)
       lwd=c(2.5,2.5),col=c("green", "red","blue"),
       cex=1.5)
abline(h=0, lwd = 2, col='black')
dev.off()
# Out:
# Plot with title “Ground Truth Thermal Response”

# %%
# plot ground truth response for HV/AC on same graph
plot(df_orig$TemperatureF, df_orig$HVAC, col='blue', type='p', lwd=2, pch='.', 
     cex.main=2, main="Ground Truth Temperature Profile", 
     cex.lab=1.5,
     cex.axis=1.2, xlab="Temperature (deg F)", ylab="Ground Truth HVAC (kWh)")
if ('HV' %in% names(df_orig))
    points(df_orig$TemperatureF, df_orig$HV, pch ='.', cex=2.5, col = rgb(1, 0, 0, 0.5), xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$resp_HV - df_resp$fit_HV.se, rev(df_resp$fit_HV + df_resp$fit_HV.se)), 
        col = rgb(1, 0, 0, 0.2), border = NA, xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$fit_HV - 2*df_resp$fit_HV.se, rev(df_resp$fit_HV + 2*df_resp$fit_HV.se)), 
        col = rgb(1, 0, 0, 0.2), border = NA, xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$fit_HV - 3*df_resp$fit_HV.se, rev(df_resp$fit_HV + 3*df_resp$fit_HV.se)), 
        col = rgb(1, 0, 0, 0.2), border = NA, xlab="")
    lines(df_resp$TemperatureF, df_resp$fit_HV, type='l', col='red', lwd=4, xlab="")

if ('AC' %in% names(df_orig))
    points(df_orig$TemperatureF, df_orig$AC, pch ='.', cex=2.5, col = rgb(0, 0, 1, 0.5), xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$fit_AC - df_resp$fit_AC.se, rev(df_resp$fit_AC + df_resp$fit_AC.se)), 
        col = rgb(0, 0, 1, 0.2), border = NA, xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$fit_AC - 2*df_resp$fit_AC.se, rev(df_resp$fit_AC + 2*df_resp$fit_AC.se)), 
        col = rgb(0, 0, 1, 0.2), border = NA, xlab="")
    polygon(c(df_resp$TemperatureF, rev(df_resp$TemperatureF)), 
            c(df_resp$fit_AC - 3*df_resp$fit_AC.se, rev(df_resp$fit_AC + 3*df_resp$fit_AC.se)), 
        col = rgb(0, 0, 1, 0.2), border = NA, xlab="")
    lines(df_resp$TemperatureF, df_resp$fit_AC, type='l', col='blue', lwd=4, xlab="")
# Out:
# Plot with title “Ground Truth Temperature Profile”

# %%
head(df_orig)
# Out:
#                     date       use AC          HV       user    lights
# 2256 2013-12-10 16:00:00 0.1192667  0 0.003266667 0.04846667 0.0360000
# 2257 2013-12-10 17:00:00 1.8549167  0 0.000000000 0.03870000 0.0360000
# 2258 2013-12-10 18:00:00 1.7488833  0 1.268766667 0.07620000 0.1075167
# 2259 2013-12-10 19:00:00 0.7415167  0 0.000000000 0.06840000 0.1391167
# 2260 2013-12-10 20:00:00 0.5380667  0 0.003550000 0.06550000 0.1589833
# 2261 2013-12-10 21:00:00 0.3783833  0 0.003666667 0.03126667 0.1459667
#        nonHVAC TemperatureF        HVAC TemperatureD    resp_HV resp_HV_se
# 2256 0.1160000     46.22333 0.003266667    -18.77667 0.06809869 0.01036297
# 2257 1.8549167     44.93500 0.000000000    -20.06500 0.08178331 0.01011705
# 2258 0.4801167     41.90000 1.268766667    -23.10000 0.12399002 0.01020426
# 2259 0.7415167     39.29167 0.000000000    -25.70833 0.17150093 0.01009171
# 2260 0.5345167     37.28167 0.003550000    -27.71833 0.21528847 0.01018839
# ...
